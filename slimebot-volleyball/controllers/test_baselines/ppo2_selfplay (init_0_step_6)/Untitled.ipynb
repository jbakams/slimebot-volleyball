# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('progress.csv')

# %%
data.head()
# Out:
#    serial_timesteps  n_updates  total_timesteps  value_loss  ep_reward_mean  \
# 0              4096          1             4096    0.184692       -5.000000
# 1              8192          2             8192    0.067610       -5.000000
# 2             12288          3            12288    0.030669       -4.965517
# 3             16384          4            16384    0.019500       -4.947368
# 4             20480          5            20480    0.011234       -4.958333
#
#    policy_loss  approxkl  clipfrac  explained_variance  policy_entropy  \
# 0    -0.003855  0.003236  0.018127           -3.264676        3.462461
# 1    -0.004033  0.003323  0.022156           -1.359121        3.452366
# 2    -0.003042  0.002670  0.012268           -0.065215        3.444242
# 3    -0.003026  0.002396  0.010742            0.325987        3.442392
# 4    -0.004206  0.003912  0.028564            0.645300        3.438652
#
#    time_elapsed  fps  ep_len_mean
# 0      0.000008  632   415.777778
# 1      6.481247  616   410.736842
# 2     13.122739  594   417.551724
# 3     20.007846  594   425.157895
# 4     26.900335  596   424.083333

# %%
plt.figure(figsize=(10,6))
plt.plot(data['total_timesteps'], data['ep_reward_mean'])

# %%
plt.figure(figsize=(10,6))
plt.plot(data['total_timesteps'], data['ep_len_mean'])

# %%
import gym
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_174177/1099527318.py in <module>
# ----> 1 import gym
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'gym'

# %%
class my_env(gym.Env):
    
    def __init__(self, render_mode = False, and_whatever_you_wanna):
        
        self.observation_space = 
        self.action_space = 
        self.t =
        self.max_t = 
        self.policy = None # in case a predefined aggents is in the env
        self.render_mode = render_mode
        
    def step(self, action):
        
        #observation: the next state due to the action applied
        #reward: the reward received
        #done: True or False that tell if the episode is over or not
        
        #return the next state, reward, done, infos
        pass
        
    def reset(self):
        #reset the env on its initial state
        
        pass
        
    def render(self):
        #display the env on a pop up screen
        pass
