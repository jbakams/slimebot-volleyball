# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('progress1.csv')

# %%
env1 = pd.read_csv('env (copy).csv')

# %%
def get_index1(data, env):
    x = [env['depth'][i] for i in range(len(env['depth'])) if env['depth'][i] != 0 ]
    
    y = [data['ep_reward_mean'][(i//4096) - 1] for i in x ]
    
    return x, y

# %%
def get_index2(data, env):
    x = [env['opponent'][i] for i in range(len(env['opponent'][:2500])) if env['opponent'][i] != 0 ]
    
    y = [data['ep_reward_mean'][(i//4096) - 1] for i in x ]
    
    return x, y

# %%
a, b = get_index1(data, env1)

# %%
c, d = get_index2(data, env1)

# %%
env1['depth'][int(700416/4096) -1]
# Out:
# 700416.0

# %%
data2 = pd.read_csv('progress2.csv')

# %%
data3 = pd.read_csv('progress3.csv')

# %%
data4 = pd.read_csv('progress.csv')

# %%
plt.figure(figsize=(10,8))
#plt.plot(data['total_timesteps'][:2500], data['ep_reward_mean'][:2500], label = 'step = 6')
#plt.plot(c, d, linestyle = '', marker = "o", markersize = 10, markeredgecolor="red", markerfacecolor="yellow")
#plt.plot(a, b, linestyle = '', marker = "d", markersize = 20, markeredgecolor="red", markerfacecolor="green")


#plt.plot(data2['total_timesteps'][:2500], data2['ep_reward_mean'][:2500], label = 'step = 6')
#plt.plot(data3['total_timesteps'][:2500], data3['ep_reward_mean'][:2500], label = 'step = 8')
plt.plot(data4['total_timesteps'][:2500], data4['ep_reward_mean'][:2500], label = 'step = 12')


plt.xlabel('Timesteps in million')
plt.ylabel('Mean rewards')
plt.legend()

# %% [markdown]
# ## Epi Length

# %%
def get_index1(data, env):
    x = [env['depth'][i] for i in range(len(env['depth'])) if env['depth'][i] != 0 ]
    
    y = [data['ep_len_mean'][(i//4096) - 1] for i in x ]
    
    return x, y

# %%
def get_index2(data, env):
    x = [env['opponent'][i] for i in range(len(env['opponent'][:2500])) if env['opponent'][i] != 0 ]
    
    y = [data['ep_len_mean'][(i//4096) - 1] for i in x ]
    
    return x, y

# %%
a, b = get_index1(data, env1)
c, d = get_index2(data, env1)

# %%
plt.figure(figsize=(10,8))
plt.plot(data['total_timesteps'][:2500], data['ep_len_mean'][:2500], label = 'step = 4')
#plt.plot(c, d, linestyle = '', marker = "o", markersize = 10, markeredgecolor="red", markerfacecolor="yellow")
#plt.plot(a, b, linestyle = '', marker = "d", markersize = 15, markeredgecolor="red", markerfacecolor="green")
plt.plot(data2['total_timesteps'][:2500], data2['ep_len_mean'][:2500], label = 'step = 6')
plt.plot(data3['total_timesteps'][:2500], data3['ep_len_mean'][:2500], label = 'step = 8')
plt.plot(data4['total_timesteps'][:2500], data4['ep_len_mean'][:2500], label = 'step = 12')


plt.xlabel('Timesteps in million')
plt.ylabel('Mean eplength')
plt.legend()

# %%
import gym
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_51897/1099527318.py in <module>
# ----> 1 import gym
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'gym'

# %%
class my_env(gym.Env):
    
    def __init__(self, render_mode = False, and_whatever_you_wanna):
        
        self.observation_space = 
        self.action_space = 
        self.t =
        self.max_t = 
        self.policy = None # in case a predefined aggents is in the env
        self.render_mode = render_mode
        
    def step(self, action):
        
        #observation: the next state due to the action applied
        #reward: the reward received
        #done: True or False that tell if the episode is over or not
        
        #return the next state, reward, done, infos
        pass
        
    def reset(self):
        #reset the env on its initial state
        
        pass
        
    def render(self):
        #display the env on a pop up screen
        pass
