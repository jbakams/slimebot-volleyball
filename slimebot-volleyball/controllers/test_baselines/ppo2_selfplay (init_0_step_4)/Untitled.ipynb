# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('progress.csv')

# %%
data.head()
# Out:
#    ep_len_mean  fps  serial_timesteps  explained_variance  approxkl  \
# 0   424.444444  641              4096           -0.759541  0.003449
# 1   425.789474  615              8192            0.348367  0.003536
# 2   422.413793  529             12288            0.683573  0.006090
# 3   421.368421  518             16384            0.747650  0.002454
# 4   421.645833  520             20480            0.761470  0.002882
#
#    total_timesteps  n_updates  value_loss  ep_reward_mean  clipfrac  \
# 0             4096          1    0.037854       -4.888889  0.018616
# 1             8192          2    0.016191       -4.894737  0.031189
# 2            12288          3    0.009173       -4.931034  0.061218
# 3            16384          4    0.009140       -4.921053  0.018982
# 4            20480          5    0.008928       -4.916667  0.017273
#
#    time_elapsed  policy_loss  policy_entropy
# 0      0.000008    -0.003603        3.462207
# 1      6.381291    -0.005530        3.456176
# 2     13.034851    -0.006714        3.450535
# 3     20.770199    -0.003467        3.444541
# 4     28.673161    -0.003872        3.434778

# %%
plt.figure(figsize=(8.3333,5))
plt.plot(data['total_timesteps'], data['ep_reward_mean'])

# %%
plt.figure(figsize=(8.3333,5))
plt.plot(data['total_timesteps'], data['ep_len_mean'])

# %%
import gym
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_174177/1099527318.py in <module>
# ----> 1 import gym
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'gym'

# %%
class my_env(gym.Env):
    
    def __init__(self, render_mode = False, and_whatever_you_wanna):
        
        self.observation_space = 
        self.action_space = 
        self.t =
        self.max_t = 
        self.policy = None # in case a predefined aggents is in the env
        self.render_mode = render_mode
        
    def step(self, action):
        
        #observation: the next state due to the action applied
        #reward: the reward received
        #done: True or False that tell if the episode is over or not
        
        #return the next state, reward, done, infos
        pass
        
    def reset(self):
        #reset the env on its initial state
        
        pass
        
    def render(self):
        #display the env on a pop up screen
        pass
